# %% [markdown]
# <a href="https://colab.research.google.com/github/vibhakarnail/upgraded-analyst/blob/master/RedCarpetUp_Assign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install nsepy
# Out:
# Requirement already satisfied: nsepy in /usr/local/lib/python3.6/dist-packages (0.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nsepy) (1.11.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from nsepy) (7.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from nsepy) (0.23.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from nsepy) (4.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from nsepy) (1.16.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from nsepy) (2.18.4)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->nsepy) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas->nsepy) (2.5.3)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->nsepy) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->nsepy) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->nsepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->nsepy) (2019.3.9)

# %%
#Source OCLHV data for NSE stocks (INFY,TCS) between 2015-2016
from datetime import date
from nsepy import get_history
infosys = get_history(symbol="INFY", 
                    start=date(2015,1,1), 
                    end=date(2016,1,1))
from datetime import date
from nsepy import get_history
tcs = get_history(symbol='TCS',
                   start=date(2015,1,1),
                   end=date(2016,1,1))
#Source OCLHV data for NIFTY IT index
from datetime import date
from nsepy import get_history
nifty= get_history(symbol='NIFTYIT',
                   start=date(2015,1,1),
                   end=date(2016,1,1))


df=pd.DataFrame(infosys)
indexes=df.index.tolist()
df['Date1'] = indexes


###############################################

l=[]

def cal(m,d,ts):
  timeseries=(ts*7)+1
  calc(m,d,timeseries)

################################################

def calc(m,d,ts):
  m=m
  ts=ts
  d=d
  dateLast=d
  yeardays=[31,28,31,30,31,30,31,31,30,31,30,31]
  dateLast=365-ts
  
  for i in range(0,12):
    dateLast-=yeardays[i]
    if ( dateLast <= 0 ):
      break
  y=i+1
  if ( dateLast == 0 ):
    x=1
  else:  
    x=dateLast+yeardays[i]+1

  calcMA(m,d,ts,x,y)   
  
############################################### 
  
def calcMA(m,d,ts,x,y):
  x=x
  y=y
  window=ts
  day1=d
  month1=m
  day=d
  month=m
  sum=0
  yeardays=[31,28,31,30,31,30,31,31,30,31,30,31]
  counter=0
  if ( month < 13 ):
    
   for ran in range(1,window):
     if ( day > yeardays[month-1] ):
        day=1
        month+=1
     if ( month > 12 ):
        break
     else:  
        a=df.loc[df['Date1']==date(2015,month,day), 'Close']
#    
        try:
         b=a[0]
        except:
         b=0
#       
        if ( b == 0 ):
#           
           day+=1
        else:
           counter+=1
           sum+=b
           day+=1  
     
  day1+=1 
  if ( counter!= 0 ):
     l.append(sum/counter)

  yeardays=[31,28,31,30,31,30,31,31,30,31,30,31]
  if ( day1 > yeardays[month1-1] ):
      day1=1
      month1+=1

  if ( day1 == x ):
      if ( month1 == y ): 
          print("done")
      else:  
          calcMA(month1,day1,window,x,y)
  else:  
      calcMA(month1,day1,window,x,y)
      
########################################
l=[]
cal(1,1,4)
print(len(l))
print(l)
# Out:
# done
# 336
# [2085.4921052631585, 2094.4973684210527, 2101.271052631579, 2101.271052631579, 2101.271052631579, 2108.6894736842105, 2117.463157894737, 2126.9, 2138.4973684210527, 2146.7105263157896, 2146.7105263157896, 2146.7105263157896, 2153.7078947368423, 2163.676315789474, 2171.8973684210528, 2181.210526315789, 2190.5684210526315, 2190.5684210526315, 2190.5684210526315, 2199.8447368421052, 2204.047222222222, 2211.0805555555553, 2218.2055555555553, 2221.986111111111, 2221.986111111111, 2221.986111111111, 2224.281578947368, 2231.4552631578945, 2240.563157894737, 2246.48947368421, 2253.007894736842, 2255.18, 2255.18, 2262.9224999999997, 2271.7699999999995, 2278.3599999999997, 2281.0499999999993, 2283.7105263157887, 2283.7105263157887, 2283.7105263157887, 2280.6131578947366, 2276.386842105263, 2270.9842105263156, 2266.0947368421052, 2262.1105263157897, 2262.1105263157897, 2262.1105263157897, 2261.4736842105262, 2260.425, 2257.0750000000003, 2252.3625, 2251.0799999999995, 2251.0799999999995, 2251.0799999999995, 2249.4724999999994, 2246.4049999999997, 2241.4799999999996, 2235.8924999999995, 2232.7124999999996, 2229.357894736842, 2229.357894736842, 2226.005263157895, 2221.821052631579, 2216.5210526315786, 2214.7944444444443, 2214.7944444444443, 2214.7944444444443, 2214.7944444444443, 2214.1361111111105, 2211.9972222222223, 2213.0166666666664, 2212.8333333333335, 2213.586111111111, 2213.586111111111, 2213.586111111111, 2212.0388888888892, 2210.3647058823526, 2209.435294117647, 2207.3294117647056, 2202.729411764706, 2202.729411764706, 2202.729411764706, 2196.770588235294, 2192.720588235294, 2187.9323529411763, 2186.5, 2174.326470588235, 2174.326470588235, 2174.326470588235, 2160.011764705883, 2144.867647058824, 2132.3500000000004, 2121.7888888888892, 2121.7888888888892, 2121.7888888888892, 2121.7888888888892, 2111.505555555556, 2100.575, 2085.102777777778, 2070.0472222222224, 2054.713888888889, 2054.713888888889, 2054.713888888889, 2041.0944444444447, 2036.1473684210528, 2022.6210526315788, 2008.9447368421054, 1997.497368421053, 1997.497368421053, 1997.497368421053, 1990.176315789474, 1983.8473684210526, 1979.0894736842108, 1975.2184210526316, 1977.9157894736838, 1977.9157894736838, 1977.9157894736838, 1979.607894736842, 1982.0500000000002, 1982.4368421052634, 1986.3500000000001, 1988.19, 1988.19, 1988.19, 1990.925, 1993.22, 1998.1625, 2002.3650000000005, 2005.05, 2005.05, 2005.05, 2005.3700000000003, 2007.6200000000001, 2011.1100000000001, 2014.2525, 2014.9175000000002, 2014.9175000000002, 2014.9175000000002, 1964.7875, 1913.6375, 1861.0574999999997, 1808.7324999999994, 1756.1774999999998, 1756.1774999999998, 1756.1774999999998, 1706.53, 1656.185, 1607.5149999999999, 1556.2075, 1505.3125, 1505.3125, 1505.3125, 1452.4299999999998, 1401.2149999999997, 1350.04, 1298.0375, 1246.97, 1246.97, 1246.97, 1196.1325000000002, 1145.5525000000002, 1092.1025, 1039.1200000000001, 987.2425, 987.2425, 987.2425, 985.2275, 983.8225, 983.2375, 982.5925, 982.9174999999998, 982.9174999999998, 982.9174999999998, 981.7874999999998, 987.4, 992.8025000000001, 998.1800000000001, 1002.2975, 1002.2975, 1002.2975, 1006.055, 1009.9799999999998, 1014.3799999999999, 1018.4799999999999, 1022.8174999999999, 1022.8174999999999, 1022.8174999999999, 1027.6, 1031.4375, 1037.8799999999999, 1045.3274999999999, 1053.2324999999998, 1053.2324999999998, 1053.2324999999998, 1060.0249999999999, 1066.92, 1074.94, 1083.3875000000003, 1090.7575000000002, 1090.7575000000002, 1090.7575000000002, 1097.8025000000002, 1100.3875, 1104.0075, 1105.8349999999998, 1108.95, 1108.95, 1108.95, 1110.2875, 1111.4275, 1110.3875, 1111.0275, 1112.7274999999997, 1112.7274999999997, 1112.7274999999997, 1113.4999999999998, 1115.0874999999999, 1115.7424999999998, 1116.3624999999997, 1115.28, 1115.28, 1115.28, 1113.9175, 1111.3999999999999, 1108.6149999999998, 1104.7375, 1101.8125, 1101.8125, 1101.8125, 1099.6925, 1096.4350000000002, 1092.7400000000002, 1090.5394736842106, 1088.1473684210528, 1088.1473684210528, 108 ...
